# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import seaborn
import cv2
import torch

from PIL import Image
from tqdm import tqdm

# %%
# !git clone https://github.com/vqdang/hover_net.git
# %cd hover_net
# Out:
# Cloning into 'hover_net'...
# remote: Enumerating objects: 2032, done.
# remote: Counting objects: 100% (496/496), done.
# remote: Compressing objects: 100% (97/97), done.
# remote: Total 2032 (delta 424), reused 401 (delta 399), pack-reused 1536 (from 1)
# Receiving objects: 100% (2032/2032), 40.39 MiB | 56.81 MiB/s, done.
# Resolving deltas: 100% (1249/1249), done.
# /mnt/storage1/Hover-Net/hover_net

# %%
# %%writefile dataset.py

import glob
import cv2
import numpy as np
import scipy.io as sio


class __AbstractDataset(object):
    """Abstract class for interface of subsequent classes.
    Main idea is to encapsulate how each dataset should parse
    their images and annotations.
    
    """

    def load_img(self, path):
        raise NotImplementedError

    def load_ann(self, path, with_type=False):
        raise NotImplementedError


####
class __PanNuke(__AbstractDataset):

    def load_img(self, path):
        return cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)

    def load_ann(self, path, with_type=False):
        # assumes that ann is HxW
        assert not with_type, "Not support"
        ann_inst = sio.loadmat(path)["inst_map"]
        ann_inst = ann_inst.astype("int32")
        ann = np.expand_dims(ann_inst, -1)
        return ann


####
def get_dataset(name):
    """Return a pre-defined dataset object associated with `name`."""
    name_dict = {
        "pannuke": lambda: __PanNuke(),
    }
    if name.lower() in name_dict:
        return name_dict[name]()
    else:
        assert False, "Unknown dataset `%s`" % name
# Out:
# Overwriting dataset.py

# %%
# %%writefile config.py

import importlib
import random

import cv2
import numpy as np

from dataset import get_dataset


class Config(object):
    """Configuration file."""

    def __init__(self):
        self.seed = 10

        self.logging = True     
        self.logging = True

        # turn on debug flag to trace some parallel processing problems more easily
        self.debug = False

        model_name = "hovernet"
        model_mode = "fast" # choose either `original` or `fast`

        if model_mode not in ["original", "fast"]:
            raise Exception("Must use either `original` or `fast` as model mode")

        nr_type = 6 # number of nuclear types (including background)

        # whether to predict the nuclear type, availability depending on dataset!
        self.type_classification = True

        # shape information - 
        # below config is for original mode. 
        # If original model mode is used, use [270,270] and [80,80] for act_shape and out_shape respectively
        # If fast model mode is used, use [256,256] and [164,164] for act_shape and out_shape respectively
        aug_shape = [540, 540] # patch shape used during augmentation (larger patch may have less border artefacts)
        act_shape = [256,256] # patch shape used as input to network - central crop performed after augmentation
        out_shape = [164,164] # patch shape at output of network

        if model_mode == "original":
            if act_shape != [270,270] or out_shape != [80,80]:
                raise Exception("If using `original` mode, input shape must be [270,270] and output shape must be [80,80]")
        if model_mode == "fast":
            if act_shape != [256,256] or out_shape != [164,164]:
                raise Exception("If using `fast` mode, input shape must be [256,256] and output shape must be [164,164]")

        self.dataset_name = "pannuke" # extracts dataset info from dataset.py
        self.log_dir = "checkpoint/" # where checkpoints will be saved

        # paths to training and validation patches
        self.train_dir_list = [
            "train/"
        ]
        self.valid_dir_list = [
            "val/"
        ]

        self.shape_info = {
            "train": {"input_shape": act_shape, "mask_shape": out_shape,},
            "valid": {"input_shape": act_shape, "mask_shape": out_shape,},
        }

        # * parsing config to the running state and set up associated variables
        self.dataset = get_dataset(self.dataset_name)

        module = importlib.import_module(
            "models.%s.opt" % model_name
        )
        self.model_config = module.get_config(nr_type, model_mode)
# Out:
# Overwriting config.py

# %%
# %%writefile hover_net/models/hovernet/opt.py

import torch.optim as optim

from run_utils.callbacks.base import (
    AccumulateRawOutput,
    PeriodicSaver,
    ProcessAccumulatedRawOutput,
    ScalarMovingAverage,
    ScheduleLr,
    TrackLr,
    VisualizeOutput,
    TriggerEngine,
)
from run_utils.callbacks.logging import LoggingEpochOutput, LoggingGradient
from run_utils.engine import Events

from .targets import gen_targets, prep_sample
from .net_desc import create_model
from .run_desc import proc_valid_step_output, train_step, valid_step, viz_step_output


# TODO: training config only ?
# TODO: switch all to function name String for all option
def get_config(nr_type, mode):
    return {
        # ------------------------------------------------------------------
        # ! All phases have the same number of run engine
        # phases are run sequentially from index 0 to N
        "phase_list": [
            {
                "run_info": {
                    # may need more dynamic for each network
                    "net": {
                        "desc": lambda: create_model(
                            input_ch=3, nr_types=nr_type, 
                            freeze=True, mode=mode
                        ),
                        "optimizer": [
                            optim.Adam,
                            {  # should match keyword for parameters within the optimizer
                                "lr": 0.0025,  # initial learning rate,
                                "betas": (0.9, 0.999),
                            },
                        ],
                        # learning rate scheduler
                        "lr_scheduler": lambda x: optim.lr_scheduler.MultiStepLR(x, milestones=[8,11]),
                        "extra_info": {
                            "loss": {
                                "np": {"bce": 1, "dice": 1},
                                "hv": {"mse": 1, "msge": 1},
                                "tp": {"bce": 1, "dice": 1},
                            },
                        },
                        # path to load, -1 to auto load checkpoint from previous phase,
                        # None to start from scratch
                        "pretrained": "../../input/preactresnet50-weights/ImageNet-ResNet50-Preact_pytorch.tar",
                        # 'pretrained': None,
                    },
                },
                "target_info": {"gen": (gen_targets, {}), "viz": (prep_sample, {})},
                "batch_size": {"train": 2, "valid": 2,},  # engine name : value
                "nr_epochs": 12,
            },
            {
                "run_info": {
                    # may need more dynamic for each network
                    "net": {
                        "desc": lambda: create_model(
                            input_ch=3, nr_types=nr_type, 
                            freeze=False, mode=mode
                        ),
                        "optimizer": [
                            optim.Adam,
                            {  # should match keyword for parameters within the optimizer
                                "lr": 0.0025,  # initial learning rate,
                                "betas": (0.9, 0.999),
                            },
                        ],
                        # learning rate scheduler
                        "lr_scheduler": lambda x: optim.lr_scheduler.MultiStepLR(x, milestones=[8,11]),
                        "extra_info": {
                            "loss": {
                                "np": {"bce": 1, "dice": 1},
                                "hv": {"mse": 1, "msge": 1},
                                "tp": {"bce": 1, "dice": 1},
                            },
                        },
                        # path to load, -1 to auto load checkpoint from previous phase,
                        # None to start from scratch
                        "pretrained": -1,
                    },
                },
                "target_info": {"gen": (gen_targets, {}), "viz": (prep_sample, {})},
                "batch_size": {"train": 2, "valid": 2,}, # batch size per gpu
                "nr_epochs": 12,
            },
        ],
        # ------------------------------------------------------------------
        # TODO: dynamically for dataset plugin selection and processing also?
        # all enclosed engine shares the same neural networks
        # as the on at the outer calling it
        "run_engine": {
            "train": {
                # TODO: align here, file path or what? what about CV?
                "dataset": "",  # whats about compound dataset ?
                "nr_procs": 16,  # number of threads for dataloader
                "run_step": train_step,  # TODO: function name or function variable ?
                "reset_per_run": False,
                # callbacks are run according to the list order of the event
                "callbacks": {
                    Events.STEP_COMPLETED: [
                        # LoggingGradient(), # TODO: very slow, may be due to back forth of tensor/numpy ?
                        ScalarMovingAverage(),
                    ],
                    Events.EPOCH_COMPLETED: [
                        TrackLr(),
                        PeriodicSaver(),
                        VisualizeOutput(viz_step_output),
                        LoggingEpochOutput(),
                        TriggerEngine("valid"),
                        ScheduleLr(),
                    ],
                },
            },
            "valid": {
                "dataset": "",  # whats about compound dataset ?
                "nr_procs": 8,  # number of threads for dataloader
                "run_step": valid_step,
                "reset_per_run": True,  # * to stop aggregating output etc. from last run
                # callbacks are run according to the list order of the event
                "callbacks": {
                    Events.STEP_COMPLETED: [AccumulateRawOutput(),],
                    Events.EPOCH_COMPLETED: [
                        # TODO: is there way to preload these ?
                        ProcessAccumulatedRawOutput(
                            lambda a: proc_valid_step_output(a, nr_types=nr_type)
                        ),
                        LoggingEpochOutput(),
                    ],
                },
            },
        },
    }
# Out:
# Overwriting hover_net/models/hovernet/opt.py

# %%
# %%writefile hover_net/models/hovernet/targets.py

import math
import numpy as np

import torch
import torch.nn.functional as F

from scipy import ndimage
from scipy.ndimage import measurements
from skimage import morphology as morph
import matplotlib.pyplot as plt

from misc.utils import center_pad_to_shape, cropping_center, get_bounding_box
from dataloader.augs import fix_mirror_padding


####
def gen_instance_hv_map(ann, crop_shape):
    """Input annotation must be of original shape.
    
    The map is calculated only for instances within the crop portion
    but based on the original shape in original image.

    Perform following operation:
    Obtain the horizontal and vertical distance maps for each
    nuclear instance.

    """
    orig_ann = ann.copy()  # instance ID map
    fixed_ann = fix_mirror_padding(orig_ann)
    # re-cropping with fixed instance id map
    crop_ann = cropping_center(fixed_ann, crop_shape)
    # TODO: deal with 1 label warning
    crop_ann = morph.remove_small_objects(crop_ann, min_size=30)

    x_map = np.zeros(orig_ann.shape[:2], dtype=np.float32)
    y_map = np.zeros(orig_ann.shape[:2], dtype=np.float32)

    inst_list = list(np.unique(crop_ann))
    inst_list.remove(0)  # 0 is background
    for inst_id in inst_list:
        inst_map = np.array(fixed_ann == inst_id, np.uint8)
        inst_box = get_bounding_box(inst_map)

        # expand the box by 2px
        # Because we first pad the ann at line 207, the bboxes
        # will remain valid after expansion
        inst_box[0] -= 2
        inst_box[2] -= 2
        inst_box[1] += 2
        inst_box[3] += 2

        inst_map = inst_map[inst_box[0] : inst_box[1], inst_box[2] : inst_box[3]]

        if inst_map.shape[0] < 2 or inst_map.shape[1] < 2:
            continue

        # instance center of mass, rounded to nearest pixel
        inst_com = list(measurements.center_of_mass(inst_map))

        inst_com[0] = int(inst_com[0] + 0.5)
        inst_com[1] = int(inst_com[1] + 0.5)

        inst_x_range = np.arange(1, inst_map.shape[1] + 1)
        inst_y_range = np.arange(1, inst_map.shape[0] + 1)
        # shifting center of pixels grid to instance center of mass
        inst_x_range -= inst_com[1]
        inst_y_range -= inst_com[0]

        inst_x, inst_y = np.meshgrid(inst_x_range, inst_y_range)

        # remove coord outside of instance
        inst_x[inst_map == 0] = 0
        inst_y[inst_map == 0] = 0
        inst_x = inst_x.astype("float32")
        inst_y = inst_y.astype("float32")

        # normalize min into -1 scale
        if np.min(inst_x) < 0:
            inst_x[inst_x < 0] /= -np.amin(inst_x[inst_x < 0])
        if np.min(inst_y) < 0:
            inst_y[inst_y < 0] /= -np.amin(inst_y[inst_y < 0])
        # normalize max into +1 scale
        if np.max(inst_x) > 0:
            inst_x[inst_x > 0] /= np.amax(inst_x[inst_x > 0])
        if np.max(inst_y) > 0:
            inst_y[inst_y > 0] /= np.amax(inst_y[inst_y > 0])

        ####
        x_map_box = x_map[inst_box[0] : inst_box[1], inst_box[2] : inst_box[3]]
        x_map_box[inst_map > 0] = inst_x[inst_map > 0]

        y_map_box = y_map[inst_box[0] : inst_box[1], inst_box[2] : inst_box[3]]
        y_map_box[inst_map > 0] = inst_y[inst_map > 0]

    hv_map = np.dstack([x_map, y_map])
    return hv_map


####
def gen_targets(ann, crop_shape, **kwargs):
    """Generate the targets for the network."""
    hv_map = gen_instance_hv_map(ann, crop_shape)
    np_map = ann.copy()
    np_map[np_map > 0] = 1

    hv_map = cropping_center(hv_map, crop_shape)
    np_map = cropping_center(np_map, crop_shape)

    target_dict = {
        "hv_map": hv_map,
        "np_map": np_map,
    }

    return target_dict


####
def prep_sample(data, is_batch=False, **kwargs):
    """
    Designed to process direct output from loader
    """
    cmap = plt.get_cmap("jet")

    def colorize(ch, vmin, vmax, shape):
        ch = np.squeeze(ch.astype("float32"))
        ch = ch / (vmax - vmin + 1.0e-16)
        # take RGB from RGBA heat map
        ch_cmap = (cmap(ch)[..., :3] * 255).astype("uint8")
        ch_cmap = center_pad_to_shape(ch_cmap, shape)
        return ch_cmap

    def prep_one_sample(data):
        shape_array = [np.array(v.shape[:2]) for v in data.values()]
        
#         for v in data.values():
#             print(np.array(v.shape[:2]))
#             raise ValueError("debugging")
#         print(shape_array)
#         print(max(shape_array, key=lambda x:np.max(x)))
#         raise ValueError("debugging")
        
        shape = max(shape_array, key=lambda x:np.max(x))
        viz_list = []
        viz_list.append(colorize(data["np_map"], 0, 1, shape))
        # map to [0,2] for better visualisation.
        # Note, [-1,1] is used for training.
        viz_list.append(colorize(data["hv_map"][..., 0] + 1, 0, 2, shape))
        viz_list.append(colorize(data["hv_map"][..., 1] + 1, 0, 2, shape))
        img = center_pad_to_shape(data["img"], shape)
        return np.concatenate([img] + viz_list, axis=1)

    # cmap may randomly fails if of other types
    if is_batch:
        viz_list = []
        data_shape = list(data.values())[0].shape
        for batch_idx in range(data_shape[0]):
            sub_data = {k : v[batch_idx] for k, v in data.items()}
            viz_list.append(prep_one_sample(sub_data))
        return np.concatenate(viz_list, axis=0)
    else:
        return prep_one_sample(data)
# Out:
# Overwriting hover_net/models/hovernet/targets.py

# %%
pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from tensorboardX) (1.23.5)
# Requirement already satisfied: packaging in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from tensorboardX) (24.1)
# Requirement already satisfied: protobuf>=3.20 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from tensorboardX) (3.20.3)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imgaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (1.23.5)
# Requirement already satisfied: scipy in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (1.10.1)
# Requirement already satisfied: Pillow in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (10.4.0)
# Requirement already satisfied: matplotlib in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (3.7.5)
# Requirement already satisfied: scikit-image>=0.14.2 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (0.14.2)
# Requirement already satisfied: opencv-python in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (4.1.2.30)
# Requirement already satisfied: imageio in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from imgaug) (2.34.2)
# Collecting Shapely (from imgaug)
#   Downloading shapely-2.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Requirement already satisfied: networkx>=1.8 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (3.1)
# Requirement already satisfied: PyWavelets>=0.4.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: dask>=1.0.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (2023.5.0)
# Requirement already satisfied: cloudpickle>=0.2.1 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from scikit-image>=0.14.2->imgaug) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from matplotlib->imgaug) (6.4.0)
# Requirement already satisfied: click>=8.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (2024.6.1)
# Requirement already satisfied: partd>=1.2.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (8.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug) (3.19.2)
# Requirement already satisfied: locket in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from partd>=1.2.0->dask>=1.0.0->dask[array]>=1.0.0->scikit-image>=0.14.2->imgaug) (1.0.0)
# Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading shapely-2.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: Shapely, imgaug
# Successfully installed Shapely-2.0.6 imgaug-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /home/skogant3/miniconda3/envs/project/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 3.8 MB/s eta 0:00:00a 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.3.2 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu115
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu115, https://pypi.ngc.nvidia.com
# Requirement already satisfied: torch in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: torchvision in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (0.7.0)
# Requirement already satisfied: torchaudio in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (0.6.0)
# Requirement already satisfied: future in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (from torch) (0.18.2)
# Requirement already satisfied: numpy in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (from torch) (1.19.1)
# Requirement already satisfied: torch in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: torch in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: pillow>=4.1.1 in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (from torchvision) (7.2.0)
# Requirement already satisfied: numpy in /home/skogant3/miniconda3/envs/hovernet/lib/python3.6/site-packages (from torch) (1.19.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
cd hover_net/
# Out:
# /mnt/storage1/Hover-Net/hover_net

# %%
# !python run_train.py --gpu='0'
# Out:
# Detect #GPUS: 1
# Using manual seed: 10
# Dataset train: 2124
# Dataset valid: 532
# Model `net` pretrained path: /mnt/storage1/Hover-Net/hover_net/input/preactresnet50-weights/ImageNet-ResNet50-Preact_pytorch.tar
# Missing Variables:
#  []
# Detected Unknown Variables:
#  []
# ----------------EPOCH 1
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Processing: |4     | 78/1062[00:10<01:26,11.44it/s]Batch = 5.95527|EMA = 5.43455/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |9    | 198/1062[00:20<01:15,11.46it/s]Batch = 6.48395|EMA = 5.48894/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 314/1062[00:30<01:04,11.52it/s]Batch = 5.21686|EMA = 5.14360/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#8   | 394/1062[00:37<00:58,11.50it/s]Batch = 5.06540|EMA = 5.32879/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#9   | 416/1062[00:39<00:56,11.46it/s]Batch = 4.43378|EMA = 5.45414/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##7  | 592/1062[00:54<00:41,11.34it/s]Batch = 4.95959|EMA = 5.20540/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###3 | 708/1062[01:05<00:31,11.41it/s]Batch = 5.26396|EMA = 4.96391/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#### | 850/1062[01:17<00:18,11.39it/s]Batch = 6.35909|EMA = 5.11341/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####3| 920/1062[01:23<00:12,11.42it/s]Batch = 4.74890|EMA = 5.09867/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:36<00:00,11.04it/s]Batch = 3.99660|EMA = 5.07114
# /mnt/storage1/Hover-Net/hover_net/models/hovernet/run_desc.py:214: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   aligned_shape = np.min(np.array(aligned_shape), axis=0)[1:3]
# ------train-loss_tp_bce  : 0.44598
# ------train-loss_tp_dice : 3.85039
# ------train-loss_np_bce  : 0.19378
# ------train-loss_np_dice : 0.27921
# ------train-loss_hv_mse  : 0.03000
# ------train-loss_hv_msge : 0.27178
# ------train-overall_loss : 5.07114
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,24.20it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,24.28it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:11<00:00,22.70it/s]
# ------valid-np_acc    : 0.92246
# ------valid-np_dice   : 0.73543
# ------valid-tp_dice_0 : 0.95735
# ------valid-tp_dice_1 : 0.64647
# ------valid-tp_dice_2 : 0.61311
# ------valid-tp_dice_3 : 0.37026
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.05191
# ------valid-hv_mse    : 0.05946
# ----------------EPOCH 2
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |4     | 81/1062[00:08<01:26,11.37it/s]Batch = 3.76833|EMA = 4.73794/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |8    | 179/1062[00:17<01:18,11.30it/s]Batch = 5.11975|EMA = 5.01046/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#    | 217/1062[00:20<01:14,11.38it/s]Batch = 5.02754|EMA = 5.10693/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##3  | 497/1062[00:45<00:49,11.33it/s]Batch = 5.12933|EMA = 4.91566/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##7  | 587/1062[00:53<00:41,11.31it/s]Batch = 6.30554|EMA = 5.03459/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####5| 965/1062[01:26<00:08,11.26it/s]Batch = 5.59275|EMA = 5.02716/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.15it/s]Batch = 4.45706|EMA = 4.95322
# ------train-loss_tp_bce  : 0.40550
# ------train-loss_tp_dice : 3.83402
# ------train-loss_np_bce  : 0.17056
# ------train-loss_np_dice : 0.26264
# ------train-loss_hv_mse  : 0.02370
# ------train-loss_hv_msge : 0.25680
# ------train-overall_loss : 4.95322
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.35it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.39it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.97it/s]
# ------valid-np_acc    : 0.94525
# ------valid-np_dice   : 0.83611
# ------valid-tp_dice_0 : 0.96481
# ------valid-tp_dice_1 : 0.69782
# ------valid-tp_dice_2 : 0.59049
# ------valid-tp_dice_3 : 0.53597
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.27920
# ------valid-hv_mse    : 0.04313
# ----------------EPOCH 3
# Processing: |       | 9/1062[00:02<07:03, 2.49it/s]Batch = 4.30518|EMA = 4.95858/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |1     | 29/1062[00:03<01:40,10.33it/s]Batch = 5.49263|EMA = 5.07064/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5     | 93/1062[00:09<01:25,11.30it/s]Batch = 4.32460|EMA = 4.93332/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5    | 115/1062[00:11<01:23,11.31it/s]Batch = 3.84861|EMA = 4.91173/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |6    | 133/1062[00:13<01:22,11.29it/s]Batch = 4.89492|EMA = 4.88441/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |7    | 165/1062[00:15<01:20,11.16it/s]Batch = 5.90137|EMA = 5.06073/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 305/1062[00:28<01:07,11.28it/s]Batch = 4.50218|EMA = 5.10559/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 315/1062[00:29<01:06,11.29it/s]Batch = 4.94268|EMA = 5.04742/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#5   | 327/1062[00:30<01:05,11.30it/s]Batch = 5.85092|EMA = 5.08065/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#9   | 411/1062[00:37<00:57,11.31it/s]Batch = 6.10928|EMA = 5.06580/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##6  | 563/1062[00:51<00:44,11.30it/s]Batch = 5.16586|EMA = 4.85075/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###7 | 793/1062[01:11<00:23,11.29it/s]Batch = 3.85406|EMA = 4.63721/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.11it/s]Batch = 3.48418|EMA = 4.87647
# ------train-loss_tp_bce  : 0.44820
# ------train-loss_tp_dice : 3.70183
# ------train-loss_np_bce  : 0.17950
# ------train-loss_np_dice : 0.25875
# ------train-loss_hv_mse  : 0.02594
# ------train-loss_hv_msge : 0.26225
# ------train-overall_loss : 4.87647
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.53it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.23it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,22.03it/s]
# ------valid-np_acc    : 0.94430
# ------valid-np_dice   : 0.84505
# ------valid-tp_dice_0 : 0.96124
# ------valid-tp_dice_1 : 0.69458
# ------valid-tp_dice_2 : 0.58930
# ------valid-tp_dice_3 : 0.51494
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.15644
# ------valid-hv_mse    : 0.04212
# ----------------EPOCH 4
# Processing: |4     | 87/1062[00:09<01:26,11.26it/s]Batch = 4.88707|EMA = 5.03008/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5     | 93/1062[00:09<01:25,11.28it/s]Batch = 5.39128|EMA = 5.06549/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5     | 97/1062[00:09<01:26,11.14it/s]Batch = 6.66522|EMA = 5.18916/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |6    | 133/1062[00:13<01:22,11.23it/s]Batch = 4.25894|EMA = 4.77685/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |7    | 157/1062[00:15<01:20,11.27it/s]Batch = 5.70665|EMA = 4.77087/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#6   | 361/1062[00:33<01:02,11.25it/s]Batch = 4.66209|EMA = 4.89589/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#7   | 379/1062[00:35<01:01,11.19it/s]Batch = 5.43687|EMA = 5.04409/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##4  | 527/1062[00:48<00:47,11.15it/s]Batch = 4.93616|EMA = 5.00281/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##5  | 537/1062[00:49<00:46,11.23it/s]Batch = 4.41298|EMA = 4.79614/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###  | 643/1062[00:58<00:37,11.12it/s]Batch = 5.04961|EMA = 4.73360/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####2| 911/1062[01:22<00:13,11.29it/s]Batch = 4.01438|EMA = 4.97835/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:36<00:00,11.05it/s]Batch = 4.86141|EMA = 4.76953
# ------train-loss_tp_bce  : 0.33251
# ------train-loss_tp_dice : 3.76407
# ------train-loss_np_bce  : 0.14375
# ------train-loss_np_dice : 0.27075
# ------train-loss_hv_mse  : 0.01965
# ------train-loss_hv_msge : 0.23879
# ------train-overall_loss : 4.76953
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.07it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.71it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,22.11it/s]
# ------valid-np_acc    : 0.94559
# ------valid-np_dice   : 0.83868
# ------valid-tp_dice_0 : 0.96568
# ------valid-tp_dice_1 : 0.63776
# ------valid-tp_dice_2 : 0.58957
# ------valid-tp_dice_3 : 0.49168
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.24716
# ------valid-hv_mse    : 0.04257
# ----------------EPOCH 5
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |2     | 53/1062[00:05<01:29,11.25it/s]Batch = 5.15917|EMA = 4.68983/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5     | 93/1062[00:09<01:25,11.31it/s]Batch = 5.98747|EMA = 5.03238/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5    | 127/1062[00:12<01:22,11.29it/s]Batch = 5.28706|EMA = 4.79549/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |7    | 165/1062[00:15<01:19,11.28it/s]Batch = 4.98743|EMA = 4.96994/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#    | 221/1062[00:20<01:14,11.31it/s]Batch = 5.29314|EMA = 4.85445/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#3   | 279/1062[00:25<01:09,11.27it/s]Batch = 4.69126|EMA = 4.65965/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 299/1062[00:27<01:07,11.30it/s]Batch = 4.01237|EMA = 4.83570/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##   | 431/1062[00:39<00:55,11.30it/s]Batch = 4.45019|EMA = 4.58451/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##   | 435/1062[00:39<00:55,11.26it/s]Batch = 4.66219|EMA = 4.66194/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##6  | 571/1062[00:51<00:43,11.26it/s]Batch = 6.99462|EMA = 5.07765/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###  | 641/1062[00:58<00:37,11.28it/s]Batch = 5.75569|EMA = 4.94316/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###4 | 723/1062[01:05<00:30,11.25it/s]Batch = 4.61589|EMA = 4.70766/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####1| 873/1062[01:18<00:16,11.30it/s]Batch = 4.66226|EMA = 4.62443/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.12it/s]Batch = 3.75780|EMA = 4.91499
# ------train-loss_tp_bce  : 0.38275
# ------train-loss_tp_dice : 3.82217
# ------train-loss_np_bce  : 0.18481
# ------train-loss_np_dice : 0.26543
# ------train-loss_hv_mse  : 0.02496
# ------train-loss_hv_msge : 0.23488
# ------train-overall_loss : 4.91499
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.14it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.35it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.82it/s]
# ------valid-np_acc    : 0.94650
# ------valid-np_dice   : 0.85145
# ------valid-tp_dice_0 : 0.96646
# ------valid-tp_dice_1 : 0.70748
# ------valid-tp_dice_2 : 0.61503
# ------valid-tp_dice_3 : 0.50745
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.32070
# ------valid-hv_mse    : 0.04271
# ----------------EPOCH 6
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |1     | 25/1062[00:03<01:50, 9.42it/s]Batch = 5.05220|EMA = 4.76647/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |3     | 63/1062[00:06<01:28,11.30it/s]Batch = 5.77144|EMA = 4.99961/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |3     | 65/1062[00:07<01:28,11.30it/s]Batch = 6.03707|EMA = 5.04583/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#5   | 323/1062[00:29<01:05,11.32it/s]Batch = 4.10201|EMA = 4.89187/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##2  | 469/1062[00:42<00:52,11.31it/s]Batch = 4.34605|EMA = 4.97478/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###4 | 723/1062[01:05<00:29,11.30it/s]Batch = 5.92821|EMA = 4.99467/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####1| 877/1062[01:19<00:16,11.29it/s]Batch = 4.50806|EMA = 4.82089/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####1| 881/1062[01:19<00:15,11.32it/s]Batch = 5.09264|EMA = 4.87112/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####3| 919/1062[01:22<00:12,11.32it/s]Batch = 3.85299|EMA = 4.77334/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###8| 1019/1062[01:31<00:03,11.33it/s]Batch = 6.05327|EMA = 4.98866/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.11it/s]Batch = 5.00000|EMA = 5.05884
# ------train-loss_tp_bce  : 0.35797
# ------train-loss_tp_dice : 3.95006
# ------train-loss_np_bce  : 0.18913
# ------train-loss_np_dice : 0.28913
# ------train-loss_hv_mse  : 0.02375
# ------train-loss_hv_msge : 0.24880
# ------train-overall_loss : 5.05884
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.23it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.32it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.89it/s]
# ------valid-np_acc    : 0.93740
# ------valid-np_dice   : 0.82881
# ------valid-tp_dice_0 : 0.96015
# ------valid-tp_dice_1 : 0.68455
# ------valid-tp_dice_2 : 0.50566
# ------valid-tp_dice_3 : 0.48563
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.24368
# ------valid-hv_mse    : 0.04630
# ----------------EPOCH 7
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |1     | 29/1062[00:03<01:39,10.40it/s]Batch = 4.22263|EMA = 4.77349/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |1     | 35/1062[00:04<01:32,11.05it/s]Batch = 5.30803|EMA = 4.84956/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |3     | 55/1062[00:06<01:28,11.34it/s]Batch = 4.83936|EMA = 4.99563/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5    | 111/1062[00:11<01:23,11.33it/s]Batch = 4.62829|EMA = 4.95167/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#3   | 283/1062[00:26<01:09,11.23it/s]Batch = 6.28435|EMA = 4.96495/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##2  | 483/1062[00:43<00:51,11.33it/s]Batch = 4.98667|EMA = 4.79603/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###2 | 687/1062[01:01<00:33,11.26it/s]Batch = 5.25429|EMA = 4.59912/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#### | 861/1062[01:17<00:17,11.31it/s]Batch = 4.65805|EMA = 4.86489/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.16it/s]Batch = 5.40652|EMA = 4.92307
# ------train-loss_tp_bce  : 0.28364
# ------train-loss_tp_dice : 3.93372
# ------train-loss_np_bce  : 0.15810
# ------train-loss_np_dice : 0.28282
# ------train-loss_hv_mse  : 0.02008
# ------train-loss_hv_msge : 0.24472
# ------train-overall_loss : 4.92307
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.23it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.35it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.88it/s]
# ------valid-np_acc    : 0.94380
# ------valid-np_dice   : 0.84198
# ------valid-tp_dice_0 : 0.96539
# ------valid-tp_dice_1 : 0.70769
# ------valid-tp_dice_2 : 0.58378
# ------valid-tp_dice_3 : 0.44399
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.24898
# ------valid-hv_mse    : 0.04215
# ----------------EPOCH 8
# Processing: |4     | 85/1062[00:08<01:26,11.27it/s]Batch = 5.79275|EMA = 5.02357/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5    | 121/1062[00:11<01:23,11.33it/s]Batch = 4.85640|EMA = 4.93171/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#2   | 259/1062[00:24<01:11,11.29it/s]Batch = 3.88511|EMA = 4.93951/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 299/1062[00:27<01:07,11.29it/s]Batch = 4.76631|EMA = 4.84791/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#5   | 331/1062[00:30<01:04,11.30it/s]Batch = 4.71392|EMA = 4.98704/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#6   | 341/1062[00:31<01:03,11.31it/s]Batch = 4.69078|EMA = 4.95219/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#8   | 385/1062[00:35<00:59,11.30it/s]Batch = 3.99145|EMA = 4.60277/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#8   | 387/1062[00:35<00:59,11.31it/s]Batch = 4.10195|EMA = 4.56552/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##7  | 585/1062[00:52<00:42,11.32it/s]Batch = 4.64107|EMA = 4.74783/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##9  | 623/1062[00:56<00:38,11.31it/s]Batch = 4.26790|EMA = 4.77981/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##9  | 637/1062[00:57<00:38,11.18it/s]Batch = 5.92361|EMA = 4.86818/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###9 | 845/1062[01:15<00:19,11.30it/s]Batch = 5.43782|EMA = 4.92773/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.14it/s]Batch = 4.76734|EMA = 4.73004
# ------train-loss_tp_bce  : 0.34766
# ------train-loss_tp_dice : 3.70704
# ------train-loss_np_bce  : 0.15516
# ------train-loss_np_dice : 0.23884
# ------train-loss_hv_mse  : 0.02288
# ------train-loss_hv_msge : 0.25845
# ------train-overall_loss : 4.73004
# ------train-lr-net       : 0.00250
# Processing: |#################8                 | 136/266[00:06<00:05,23.13it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.21it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.84it/s]
# ------valid-np_acc    : 0.94391
# ------valid-np_dice   : 0.83498
# ------valid-tp_dice_0 : 0.96412
# ------valid-tp_dice_1 : 0.67810
# ------valid-tp_dice_2 : 0.57137
# ------valid-tp_dice_3 : 0.53262
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.20406
# ------valid-hv_mse    : 0.04102
# ----------------EPOCH 9
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |       | 5/1062[00:01<12:14, 1.44it/s]Batch = 5.34803|EMA = 4.78443/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |3     | 65/1062[00:06<01:28,11.29it/s]Batch = 4.89233|EMA = 4.73773/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |5     | 95/1062[00:09<01:25,11.34it/s]Batch = 5.22265|EMA = 4.77725/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |8    | 183/1062[00:17<01:17,11.28it/s]Batch = 4.27674|EMA = 4.81068/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |9    | 193/1062[00:18<01:16,11.30it/s]Batch = 4.86388|EMA = 4.80597/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#6   | 343/1062[00:31<01:03,11.31it/s]Batch = 4.52008|EMA = 4.58249/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##   | 425/1062[00:38<00:56,11.35it/s]Batch = 5.02568|EMA = 4.83569/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##8  | 611/1062[00:55<00:39,11.32it/s]Batch = 6.28398|EMA = 4.67669/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####2| 901/1062[01:20<00:14,11.21it/s]Batch = 4.84401|EMA = 4.63759/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####5| 975/1062[01:27<00:07,11.31it/s]Batch = 5.04387|EMA = 4.84572/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[01:35<00:00,11.14it/s]Batch = 4.45561|EMA = 4.38992
# ------train-loss_tp_bce  : 0.28193
# ------train-loss_tp_dice : 3.47998
# ------train-loss_np_bce  : 0.14432
# ------train-loss_np_dice : 0.23183
# ------train-loss_hv_mse  : 0.02079
# ------train-loss_hv_msge : 0.23107
# ------train-overall_loss : 4.38992
# ------train-lr-net       : 0.00025
# Processing: |#################8                 | 136/266[00:06<00:05,23.54it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.56it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:11<00:00,22.17it/s]
# ------valid-np_acc    : 0.94595
# ------valid-np_dice   : 0.84843
# ------valid-tp_dice_0 : 0.96469
# ------valid-tp_dice_1 : 0.69338
# ------valid-tp_dice_2 : 0.44035
# ------valid-tp_dice_3 : 0.52301
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.17213
# ------valid-hv_mse    : 0.04122
# ----------------EPOCH 10
# Processing: |       | 3/1062[00:01<16:36, 1.06it/s]Batch = 5.02003|EMA = 4.49504/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# Processing: |8    | 178/1062[00:27<02:08, 6.89it/s]Batch = 5.54754|EMA = 5.23519/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#3   | 286/1062[00:42<01:52, 6.91it/s]Batch = 4.87604|EMA = 5.08591/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#7   | 375/1062[00:55<01:39, 6.90it/s]Batch = 5.34823|EMA = 5.12280/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##   | 437/1062[01:04<01:32, 6.79it/s]Batch = 5.22851|EMA = 5.03838/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##4  | 527/1062[01:17<01:17, 6.89it/s]Batch = 4.00766|EMA = 4.96673/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##6  | 573/1062[01:24<01:11, 6.83it/s]Batch = 5.32090|EMA = 5.05866/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###8 | 824/1062[02:00<00:34, 6.89it/s]Batch = 5.45088|EMA = 5.16443/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###8 | 828/1062[02:01<00:33, 6.89it/s]Batch = 5.05423|EMA = 5.19340/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####1| 880/1062[02:09<00:26, 6.89it/s]Batch = 5.78568|EMA = 5.07238/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####6| 982/1062[02:23<00:11, 6.89it/s]Batch = 6.15416|EMA = 5.14690/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[02:35<00:00, 6.82it/s]Batch = 4.64526|EMA = 5.06235
# ------train-loss_tp_bce  : 0.37667
# ------train-loss_tp_dice : 3.93423
# ------train-loss_np_bce  : 0.18574
# ------train-loss_np_dice : 0.28348
# ------train-loss_hv_mse  : 0.02498
# ------train-loss_hv_msge : 0.25726
# ------train-overall_loss : 5.06235
# ------train-lr-net       : 0.00025
# Processing: |#################8                 | 136/266[00:06<00:05,23.40it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.43it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,21.94it/s]
# ------valid-np_acc    : 0.93290
# ------valid-np_dice   : 0.79574
# ------valid-tp_dice_0 : 0.95654
# ------valid-tp_dice_1 : 0.58056
# ------valid-tp_dice_2 : 0.54120
# ------valid-tp_dice_3 : 0.38715
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.07474
# ------valid-hv_mse    : 0.04896
# ----------------EPOCH 11
# Processing: |3     | 56/1062[00:09<02:26, 6.88it/s]Batch = 4.41595|EMA = 5.18822/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |3     | 63/1062[00:10<02:24, 6.91it/s]Batch = 4.24816|EMA = 5.07829/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#    | 214/1062[00:32<02:03, 6.89it/s]Batch = 5.61199|EMA = 5.02379/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#2   | 256/1062[00:38<01:56, 6.90it/s]Batch = 4.89156|EMA = 5.08775/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#6   | 345/1062[00:51<01:43, 6.90it/s]Batch = 5.21978|EMA = 4.99077/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#9   | 417/1062[01:01<01:33, 6.90it/s]Batch = 4.95736|EMA = 5.17540/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###  | 651/1062[01:35<01:00, 6.85it/s]Batch = 2.93139|EMA = 5.25984/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###6 | 771/1062[01:53<00:42, 6.91it/s]Batch = 5.75248|EMA = 5.08027/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###9 | 844/1062[02:03<00:31, 6.90it/s]Batch = 5.31581|EMA = 4.98249/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#### | 861/1062[02:06<00:29, 6.90it/s]Batch = 5.71988|EMA = 5.06311/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####5| 974/1062[02:22<00:12, 6.91it/s]Batch = 5.92050|EMA = 5.18419/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[02:35<00:00, 6.84it/s]Batch = 4.53758|EMA = 4.96685
# ------train-loss_tp_bce  : 0.35539
# ------train-loss_tp_dice : 3.88026
# ------train-loss_np_bce  : 0.15849
# ------train-loss_np_dice : 0.27528
# ------train-loss_hv_mse  : 0.02376
# ------train-loss_hv_msge : 0.27368
# ------train-overall_loss : 4.96685
# ------train-lr-net       : 0.00025
# Processing: |#################8                 | 136/266[00:06<00:05,23.84it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.73it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:11<00:00,22.27it/s]
# ------valid-np_acc    : 0.93530
# ------valid-np_dice   : 0.80562
# ------valid-tp_dice_0 : 0.95936
# ------valid-tp_dice_1 : 0.60071
# ------valid-tp_dice_2 : 0.55044
# ------valid-tp_dice_3 : 0.42134
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.07454
# ------valid-hv_mse    : 0.04818
# ----------------EPOCH 12
# Processing: |                       | 0/1062[00:00<?,?it/s]Batch = nan|EMA = nan/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |       | 8/1062[00:02<04:27, 3.94it/s]Batch = 5.88593|EMA = 5.02386/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |      | 16/1062[00:03<02:37, 6.66it/s]Batch = 5.20375|EMA = 5.01456/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |9    | 199/1062[00:30<02:05, 6.90it/s]Batch = 5.35173|EMA = 4.94602/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#1   | 239/1062[00:35<01:59, 6.91it/s]Batch = 5.45836|EMA = 5.11072/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#2   | 257/1062[00:38<01:56, 6.91it/s]Batch = 4.71218|EMA = 4.97585/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |#4   | 313/1062[00:46<01:48, 6.91it/s]Batch = 5.36145|EMA = 5.00070/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###2 | 684/1062[01:40<00:54, 6.88it/s]Batch = 5.26393|EMA = 5.16536/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###2 | 699/1062[01:42<00:52, 6.89it/s]Batch = 5.88283|EMA = 5.14018/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###7 | 798/1062[01:57<00:38, 6.92it/s]Batch = 4.40502|EMA = 4.96971/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###7 | 802/1062[01:57<00:37, 6.91it/s]Batch = 6.02516|EMA = 5.08967/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###8 | 820/1062[02:00<00:35, 6.86it/s]Batch = 5.26674|EMA = 5.10475/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |####| 1062/1062[02:35<00:00, 6.83it/s]Batch = 4.22697|EMA = 5.08034
# ------train-loss_tp_bce  : 0.41430
# ------train-loss_tp_dice : 3.88201
# ------train-loss_np_bce  : 0.20612
# ------train-loss_np_dice : 0.29098
# ------train-loss_hv_mse  : 0.02664
# ------train-loss_hv_msge : 0.26030
# ------train-overall_loss : 5.08034
# ------train-lr-net       : 0.00003
# Processing: |#################8                 | 136/266[00:06<00:05,23.81it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# /home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |##############################9    | 235/266[00:10<00:01,23.85it/s]/home/skogant3/miniconda3/envs/new_hovernet/lib/python3.7/site-packages/skimage/_shared/utils.py:157: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   return func(*args, **kwargs)
# Processing: |###################################| 266/266[00:12<00:00,22.16it/s]
# ------valid-np_acc    : 0.93581
# ------valid-np_dice   : 0.81379
# ------valid-tp_dice_0 : 0.95874
# ------valid-tp_dice_1 : 0.61267
# ------valid-tp_dice_2 : 0.55183
# ------valid-tp_dice_3 : 0.39935
# ------valid-tp_dice_4 : 0.00000
# ------valid-tp_dice_5 : 0.07393
# ------valid-hv_mse    : 0.04831
#
#
# ########################################################
# ########################################################
